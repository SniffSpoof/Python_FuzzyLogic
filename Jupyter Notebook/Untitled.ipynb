# %%
from matplotlib import pylab as plt
from matplotlib import colors
import numpy as np
import math
from itertools import product
import fuzzy_funcs
import fuzzy_kvant
import fuzzy_logic

# %%
U1 = fuzzy_funcs.generate_U(0, 100, 2)

for i in range(0, 10):
    a = 70 + 10*i; c = 40 - i*10; b = (a+c)/2;
    z = fuzzy_funcs.PI_func(U1, a, b, c)
    plt.plot(U1, z)


plt.show()

# %%
test = fuzzy_logic.exemple("PI", 0, 100, 10, 90, 50, 2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-8cef97c3df65> in <module>()
# ----> 1 test = fuzzy_logic.exemple("PI", 0, 100, 10, 90, 50, 2)
#
# ~\Desktop\Проект-исследование по математике\code\fuzzy_logic.py in __init__(self, type, U1, U2, a, c, epsilon, b)
#       6                         (a+c)/2
#       7                 #init of params
# ----> 8                 self.U = fuzzy_funcs.generate_U(U1, U2, epsilon)
#       9                 self.a = a
#      10                 self.b = b
#
# ~\Desktop\Проект-исследование по математике\code\fuzzy_funcs.py in generate_U(a, b, epsilon)
#     106         U = []
#     107         for i in range(a*(10**epsilon), b*(10**epsilon)):
# --> 108             U.append(i/(10**epsilon))
#     109         U.append(b/1.0)
#     110         return U
#
# KeyboardInterrupt:
